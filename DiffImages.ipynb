# %% [markdown]
# <a href="https://colab.research.google.com/github/gabilodeau/INF6804/blob/master/DiffImages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INF6804 Vision par ordinateur
#
# Polytechnique Montréal
#
# Différence de deux images dans une séquence vidéo

# %% [markdown]
# Exécuter les 2 lignes suivantes pour colab.

# %%
# !git clone https://github.com/gabilodeau/INF6804
# %cd INF6804
# Out:
# Cloning into 'INF6804'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 266 (delta 46), reused 24 (delta 6), pack-reused 165
# Receiving objects: 100% (266/266), 31.61 MiB | 32.79 MiB/s, done.
# Resolving deltas: 100% (108/108), done.
# /content/INF6804

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Lecture de deux trames

# %%
image1 = (cv2.imread('images/in000235.jpg',cv2.IMREAD_GRAYSCALE)).astype(float)
plt.imshow(image1, cmap = plt.get_cmap('gray'))
plt.show()
image2 = (cv2.imread('images/in000240.jpg',cv2.IMREAD_GRAYSCALE)).astype(float)
plt.imshow(image2, cmap = plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# Différence des deux trames, et affichage des différences

# %%
Diffimage = np.abs(image1 - image2)
fig1 = plt.figure(figsize = (10,10))
plt.imshow(Diffimage, cmap = plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# Notez qu'on détecte des changements à la nouvelle et à l'ancienne position.
