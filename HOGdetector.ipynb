# %% [markdown]
# <a href="https://colab.research.google.com/github/gabilodeau/INF6804/blob/master/HOGdetector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INF6804 Vision par ordinateur
#
# Polytechnique Montréal
#
# Exemple de détection avec HOG + SVM

# %% [markdown]
# Exécuter les 2 lignes suivantes pour colab.

# %%
# !git clone https://github.com/gabilodeau/INF6804
# %cd INF6804
# Out:
# Cloning into 'INF6804'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 319 (delta 75), reused 25 (delta 7), pack-reused 165
# Receiving objects: 100% (319/319), 32.98 MiB | 19.41 MiB/s, done.
# Resolving deltas: 100% (137/137), done.
# /content/INF6804

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Lecture des images en entrée. (Images provenant PETS 2006, http://www.cvg.reading.ac.uk/PETS2006/data.html)

# %%
image1 = (cv2.imread('images/in000235.jpg',cv2.IMREAD_GRAYSCALE))
image2 = (cv2.imread('images/in000216.jpg',cv2.IMREAD_GRAYSCALE))

# %% [markdown]
# Initialisation du détecteur.

# %%
hog = cv2.HOGDescriptor() #64 x 128 pixels
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# %% [markdown]
# Détection multi-échelles et affichage.

# %%
(rects, weights) = hog.detectMultiScale(image1, winStride = (4,4), padding = (8,8), scale = 1.05)

#Affichage
for (x, y, w, h) in rects:
    cv2.rectangle(image1, (x, y), (x + w, y + h), (255, 255, 255), 2)
    
plt.figure(figsize = (8,8))
plt.imshow(image1, cmap = plt.get_cmap('gray'))
plt.show()

# %%
print(weights) #Score des détections
# Out:
# [[2.08160793]
#  [0.79433504]]

# %% [markdown]
# Détection multi-échelles et affichage.

# %%
(rects, weights) = hog.detectMultiScale(image2, winStride=(2,2), padding= (8,8), scale=1.05)

#Affichage
for (x, y, w, h) in rects:
    cv2.rectangle(image2, (x, y), (x + w, y + h), (255, 255, 255), 2)
    
plt.figure(figsize = (8,8))
plt.imshow(image2, cmap = plt.get_cmap('gray'))
plt.show()

# %%
print(weights) #Score des détections
# Out:
# [[2.89795461]
#  [0.80158425]
#  [0.44792987]
#  [0.44403013]
#  [0.31446548]
#  [0.33915243]]
