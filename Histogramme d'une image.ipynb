# %% [markdown]
# INF6804 Vision par ordinateur
#
# Polytechnique Montréal
#
# Histogramme d'une image

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Lecture de l'image. (Image provenant de PETS 2006, http://www.cvg.reading.ac.uk/PETS2006/data.html)

# %%
image = cv2.imread('in000235.jpg') #OpenCV lit les images en BGR
b,g,r = cv2.split(image)
image = cv2.merge([r,g,b])
plt.imshow(image)
plt.show()

# %% [markdown]
# Calcul de l'histogramme de chaque canal.

# %%
hist = cv2.calcHist([image],[0],None,[256],[0,256])
plt.plot(hist,'r')
hist = cv2.calcHist([image],[1],None,[256],[0,256])
plt.plot(hist,'g')
hist = cv2.calcHist([image],[2],None,[256],[0,256])
plt.plot(hist,'b')
plt.show()

# %%
print(hist)
# Out:
# [[3.802e+03]
#  [7.960e+02]
#  [7.460e+02]
#  [8.700e+02]
#  [9.650e+02]
#  [1.220e+03]
#  [1.481e+03]
#  [1.748e+03]
#  [1.977e+03]
#  [2.068e+03]
#  [2.158e+03]
#  [2.114e+03]
#  [2.213e+03]
#  [2.136e+03]
#  [2.255e+03]
#  [2.337e+03]
#  [2.277e+03]
#  [2.245e+03]
#  [2.263e+03]
#  [2.137e+03]
#  [2.017e+03]
#  [1.900e+03]
#  [1.922e+03]
#  [1.794e+03]
#  [1.746e+03]
#  [1.747e+03]
#  [1.693e+03]
#  [1.763e+03]
#  [1.672e+03]
#  [1.648e+03]
#  [1.569e+03]
#  [1.568e+03]
#  [1.646e+03]
#  [1.546e+03]
#  [1.585e+03]
#  [1.764e+03]
#  [1.720e+03]
#  [1.763e+03]
#  [1.790e+03]
#  [1.846e+03]
#  [1.971e+03]
#  [2.172e+03]
#  [2.291e+03]
#  [2.473e+03]
#  [2.607e+03]
#  [2.833e+03]
#  [2.883e+03]
#  [2.937e+03]
#  [3.060e+03]
#  [3.475e+03]
#  [3.546e+03]
#  [3.847e+03]
#  [4.017e+03]
#  [4.183e+03]
#  [4.255e+03]
#  [4.115e+03]
#  [3.999e+03]
#  [3.676e+03]
#  [3.286e+03]
#  [3.130e+03]
#  [2.683e+03]
#  [2.456e+03]
#  [2.217e+03]
#  [2.033e+03]
#  [1.925e+03]
#  [1.853e+03]
#  [1.902e+03]
#  [1.900e+03]
#  [1.838e+03]
#  [1.816e+03]
#  [1.733e+03]
#  [1.661e+03]
#  [1.615e+03]
#  [1.628e+03]
#  [1.543e+03]
#  [1.421e+03]
#  [1.294e+03]
#  [1.284e+03]
#  [1.243e+03]
#  [1.142e+03]
#  [1.072e+03]
#  [9.580e+02]
#  [9.070e+02]
#  [9.180e+02]
#  [8.300e+02]
#  [8.900e+02]
#  [9.350e+02]
#  [9.150e+02]
#  [9.290e+02]
#  [9.870e+02]
#  [9.740e+02]
#  [9.980e+02]
#  [9.730e+02]
#  [1.067e+03]
#  [1.067e+03]
#  [1.053e+03]
#  [1.061e+03]
#  [1.080e+03]
#  [1.134e+03]
#  [1.101e+03]
#  [1.122e+03]
#  [1.222e+03]
#  [1.224e+03]
#  [1.145e+03]
#  [1.209e+03]
#  [1.257e+03]
#  [1.219e+03]
#  [1.181e+03]
#  [1.249e+03]
#  [1.195e+03]
#  [1.294e+03]
#  [1.388e+03]
#  [1.517e+03]
#  [1.576e+03]
#  [1.750e+03]
#  [1.971e+03]
#  [2.047e+03]
#  [2.004e+03]
#  [2.179e+03]
#  [2.258e+03]
#  [2.384e+03]
#  [2.477e+03]
#  [2.621e+03]
#  [2.876e+03]
#  [3.103e+03]
#  [3.572e+03]
#  [3.971e+03]
#  [4.472e+03]
#  [4.868e+03]
#  [5.401e+03]
#  [5.784e+03]
#  [6.427e+03]
#  [7.141e+03]
#  [7.662e+03]
#  [8.074e+03]
#  [8.508e+03]
#  [8.661e+03]
#  [8.743e+03]
#  [8.223e+03]
#  [7.782e+03]
#  [7.109e+03]
#  [6.643e+03]
#  [6.171e+03]
#  [5.872e+03]
#  [5.593e+03]
#  [5.670e+03]
#  [5.328e+03]
#  [4.992e+03]
#  [4.593e+03]
#  [4.106e+03]
#  [3.444e+03]
#  [3.039e+03]
#  [2.411e+03]
#  [2.071e+03]
#  [1.717e+03]
#  [1.470e+03]
#  [1.224e+03]
#  [1.012e+03]
#  [8.150e+02]
#  [7.270e+02]
#  [6.490e+02]
#  [5.240e+02]
#  [4.440e+02]
#  [3.670e+02]
#  [3.260e+02]
#  [2.860e+02]
#  [2.730e+02]
#  [2.400e+02]
#  [2.420e+02]
#  [2.240e+02]
#  [2.030e+02]
#  [1.560e+02]
#  [1.620e+02]
#  [1.350e+02]
#  [1.430e+02]
#  [1.120e+02]
#  [1.060e+02]
#  [9.500e+01]
#  [8.900e+01]
#  [7.400e+01]
#  [7.400e+01]
#  [7.300e+01]
#  [6.800e+01]
#  [5.800e+01]
#  [6.100e+01]
#  [7.000e+01]
#  [5.000e+01]
#  [6.200e+01]
#  [5.700e+01]
#  [5.100e+01]
#  [4.400e+01]
#  [4.600e+01]
#  [2.600e+01]
#  [2.800e+01]
#  [1.700e+01]
#  [1.300e+01]
#  [4.000e+00]
#  [3.000e+00]
#  [0.000e+00]
#  [1.000e+00]
#  [1.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]]

# %%
hist.shape
# Out:
# (256, 1)
