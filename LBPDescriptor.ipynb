# %% [markdown]
# <a href="https://colab.research.google.com/github/gabilodeau/INF6804/blob/master/LBPDescriptor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INF6804 Vision par ordinateur
#
# Polytechnique Montréal
#
# Exemple d'utilisation de LBP

# %%
import numpy as np
from skimage import data
from skimage.feature.texture import local_binary_pattern
import matplotlib.pyplot as plt

# %% [markdown]
# Obtention d'une image de skimage. Affichage.

# %%
image = data.camera() 
plt.figure(figsize=(6,6)) 
plt.imshow(image, cmap='gray')
plt.show()

# %% [markdown]
# Application de LBP sur l'image pour des codes d'une taille donnée et pour un rayon prédéfini.

# %%
longueurCodes = 8
rayon = 1
codes = local_binary_pattern(image, longueurCodes, rayon)

# %% [markdown]
# Analyse du résultat sur une portion d'image.

# %%
print(image[270:278,200:208])
# Out:
# [[51 48 40 31 23 17 14 13]
#  [45 37 29 26 24 19 16 14]
#  [33 26 21 20 21 17 15 13]
#  [21 18 17 17 18 16 14 13]
#  [15 16 18 17 17 14 13 12]
#  [13 17 21 19 17 14 13 13]
#  [11 14 17 16 14 13 13 12]
#  [12 12 13 13 13 13 14 13]]

# %% [markdown]
# Codes obtenus pour cette portion d'image.

# %%
print(codes[270:278,200:208])
# Out:
# [[  6.  28.  28.  28. 120. 120. 248. 255.]
#  [ 14.  30.  30.  28.  24.  56.  56.  57.]
#  [ 30.  30.  30.  31.  12.  60.  60. 255.]
#  [ 30.  30. 223. 255.  12.  60.  60. 191.]
#  [159. 207. 192. 255. 124. 126. 126. 255.]
#  [143. 131.   0.  16.  28.  60. 125. 147.]
#  [239.   7.  14.  30.  30. 255. 252. 255.]
#  [195. 247.  15.  31. 223. 255.  96. 121.]]

# %% [markdown]
# Les codes affichés sont les chaînes $longueurCodes$ bits en entiers non-signés. On peut détailler les codes avec:

# %%
code = 30
"{0:08b}".format(code)
# Out:
# '00011110'

# %% [markdown]
# Normalement, on fait des statistiques sur le nombre de répétitions des codes. Et cela nous donne le descripteur.

# %%
hist, _ = np.histogram(codes, 256, range=(0, 256))
plt.plot(hist)
plt.show()
